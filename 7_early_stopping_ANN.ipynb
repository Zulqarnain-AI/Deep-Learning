# %%
from gc import callbacks

import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.datasets import make_circles

# %%
x,y = make_circles(n_samples=200, noise=0.1, random_state=1)

# %%
sns.scatterplot(x=x[:,0],y=x[:,1],hue=y)
# Out:
# <Axes: >

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model= Sequential()
model.add(Dense(256,activation='relu',input_dim=2))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=500,verbose=0)

# %%
plt.plot(history.history['loss'],label = 'train')
plt.plot(history.history['val_loss'],label = 'test')

# %% [markdown]
# # early stopping

# %%
model1= Sequential()
model1.add(Dense(256,activation='relu',input_dim=2))
model1.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
callback = EarlyStopping(
    monitor='val_loss',
    min_delta=0.00001,
    patience=20,
    verbose=1,
    mode='auto',
    baseline=None,
    restore_best_weights=False,
)

# %%
history1 = model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=500,callbacks=[callback])
# Out:
# Epoch 1/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.9000 - loss: 0.2370 - val_accuracy: 0.8500 - val_loss: 0.2841
# Epoch 2/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8875 - loss: 0.2289 - val_accuracy: 0.8250 - val_loss: 0.3075
# Epoch 3/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8750 - loss: 0.2302 - val_accuracy: 0.8250 - val_loss: 0.3384
# Epoch 4/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8875 - loss: 0.2293 - val_accuracy: 0.8250 - val_loss: 0.3511
# Epoch 5/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8938 - loss: 0.2313 - val_accuracy: 0.8250 - val_loss: 0.3293
# Epoch 6/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9062 - loss: 0.2287 - val_accuracy: 0.8250 - val_loss: 0.3116
# Epoch 7/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9000 - loss: 0.2284 - val_accuracy: 0.8250 - val_loss: 0.3039
# Epoch 8/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9000 - loss: 0.2284 - val_accuracy: 0.8250 - val_loss: 0.3208
# Epoch 9/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8813 - loss: 0.2285 - val_accuracy: 0.8250 - val_loss: 0.3288
# Epoch 10/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8875 - loss: 0.2272 - val_accuracy: 0.8250 - val_loss: 0.3169
# Epoch 11/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8875 - loss: 0.2275 - val_accuracy: 0.8250 - val_loss: 0.3115
# Epoch 12/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9000 - loss: 0.2272 - val_accuracy: 0.8250 - val_loss: 0.3053
# Epoch 13/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9000 - loss: 0.2277 - val_accuracy: 0.8250 - val_loss: 0.3162
# Epoch 14/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9000 - loss: 0.2272 - val_accuracy: 0.8250 - val_loss: 0.3169
# Epoch 15/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8938 - loss: 0.2274 - val_accuracy: 0.8250 - val_loss: 0.3246
# Epoch 16/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8813 - loss: 0.2276 - val_accuracy: 0.8250 - val_loss: 0.3147
# Epoch 17/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8938 - loss: 0.2276 - val_accuracy: 0.8250 - val_loss: 0.3115
# Epoch 18/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9000 - loss: 0.2272 - val_accuracy: 0.8250 - val_loss: 0.3148
# Epoch 19/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9000 - loss: 0.2276 - val_accuracy: 0.8250 - val_loss: 0.3118
# Epoch 20/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9000 - loss: 0.2277 - val_accuracy: 0.8250 - val_loss: 0.3114
# Epoch 21/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8875 - loss: 0.2278 - val_accuracy: 0.8250 - val_loss: 0.3269
# Epoch 21: early stopping

# %%
plt.plot(history1.history['loss'],label = 'train')
plt.plot(history1.history['val_loss'],label = 'test')
